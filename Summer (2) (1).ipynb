# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
df['City'].unique
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
df = df[df['Medal']=='Gold']
data=[]
for Sport in df['Sport'].unique():
    data.append([Sport,len(df[df['Sport']==Sport])])
data=pd.DataFrame(data,columns=['Sport','freq']).sort_values(by='freq',ascending = False).head()
data
data.plot(x='Sport',y='freq',kind = 'bar',figsize=(8,5))

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
data=[]
for Medal in df['Sport'].unique():
    data.append([Medal,len(df[df['Sport']==Medal])])
data= pd.DataFrame(data,columns=['Sport','freq'])
data= data.sort_values(by='freq',ascending = False).head()
data
data.plot(x='Sport',y='freq',kind='bar',figsize = (8,5))

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
data=[]
for Medal in df['Athlete'].unique():
    data.append([Medal,len(df[df['Athlete']== Medal])])
data= pd.DataFrame(data,columns=['Athlete','freq'])
data= data.sort_values(by='freq',ascending = False).head()
data
data.plot(x='Athlete',y='freq',kind='bar',figsize = (8,5))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
df = df[df['Medal']=='Gold']
data=[]
for Athlete in df['Athlete'].unique():
    data.append([Athlete,len(df[df['Athlete']==Athlete])])
data=pd.DataFrame(data,columns=['Athlete','freq']).sort_values(by='freq',ascending = False).head()
data
data.plot(x='Athlete',y='freq',kind = 'bar',figsize=(8,5))

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
df = df[df['Country']=='IND']
df = df[df['Medal']=='Gold']
df.head(1)
# Out:
#       Year       City   Sport Discipline               Athlete Country Gender  \
# 5512  1928  Amsterdam  Hockey     Hockey  ALLEN, Richard James     IND    Men
#
#        Event Medal
# 5512  Hockey  Gold

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
data=[]
for Athlete in df['Event'].unique():
    data.append([Athlete,len(df[df['Event']==Athlete ])])
data= pd.DataFrame(data,columns=['Event','freq'])
data= data.sort_values(by='freq',ascending = False).head()
data
data.plot(x='Event',y='freq',kind='bar',figsize = (8,5))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("E:/ds_sdm/summer.csv")
df_females = df[df['Gender'] == 'Women']
df_females_gold = df_females[df_females['Medal']=='Gold']
data=[]
for sport in df_females_gold['Sport'].unique():
    data.append([sport, len(df_females_gold[df_females_gold['Sport'] == sport])])
data = pd.DataFrame(data, columns=['Sport','freq']).sort_values(by='freq',ascending = False)
data.head(1)
# Out:
#       Sport  freq
# 4  Aquatics   589
